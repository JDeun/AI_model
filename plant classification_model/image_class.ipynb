# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
from PIL import Image

def load_and_preprocess_image(image_path, target_size):
    """이미지를 로드하고 전처리하는 함수"""
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # 배치 차원 추가
    img_array = img_array.astype('float32') / 255.0
    return img_array

def classify_and_save_images(model, input_dir, output_dir, target_size=(224, 224)):
    """이미지를 분류하고 결과에 따라 저장하는 함수"""
    # 하위 폴더 생성
    can_use_dir = os.path.join(output_dir, 'can_use')
    can_not_use_dir = os.path.join(output_dir, 'can_not_use')
    os.makedirs(can_use_dir, exist_ok=True)
    os.makedirs(can_not_use_dir, exist_ok=True)
    
    # 모든 이미지 파일 경로 리스트
    image_files = [f for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]
    
    for img_name in image_files:
        img_path = os.path.join(input_dir, img_name)
        img_array = load_and_preprocess_image(img_path, target_size)
        
        # 이미지 분류
        prediction = model.predict(img_array)
        class_index = int(np.round(prediction[0][0]))  # 0 또는 1로 변환
        
        # 분류 결과에 따른 폴더에 이미지 저장
        dest_folder = can_use_dir if class_index == 0 else can_not_use_dir
        dest_path = os.path.join(dest_folder, img_name)
        
        # 이미지 복사 및 저장
        img = Image.open(img_path)
        # 'P' 모드 이미지를 'RGB'로 변환
        if img.mode == 'P':
            img = img.convert('RGB')
        img.save(dest_path)
        print(f"이미지 {img_name}를 {('can_use' if class_index == 0 else 'can_not_use')} 폴더에 저장했습니다.")

def main():
    # 사용자로부터 모델 경로, 입력 폴더 및 출력 폴더 경로를 입력받습니다.
    model_path = input("저장된 모델의 경로를 입력하세요 (예: C:/temp/plant_classification_AI.h5): ").strip()
    input_dir = input("분류할 이미지들이 있는 폴더의 경로를 입력하세요: ").strip()
    output_dir = input("이미지 분류 결과를 저장할 폴더의 경로를 입력하세요: ").strip()
    
    # 저장된 모델 로드
    if not os.path.exists(model_path):
        print(f"모델 파일이 존재하지 않습니다: {model_path}")
        return
    
    model = load_model(model_path)
    
    # 이미지 분류 및 저장
    classify_and_save_images(model, input_dir, output_dir)

if __name__ == "__main__":
    main()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 이미지 Nepeta cataria_10_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_10_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 이미지 Nepeta cataria_10_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_10_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_10_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_10_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_10_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_10_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_10_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_10_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_10_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_10_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_10_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_10_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_10_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_10_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_10_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_10_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_10_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_10_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_11_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_11_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 이미지 Nepeta cataria_11_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_11_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_11_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_11_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_11_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_11_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_11_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 이미지 Nepeta cataria_11_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_11_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_11_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_11_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_11_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_11_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_11_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_11_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 이미지 Nepeta cataria_11_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_11_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_11_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_12_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_12_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_12_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_12_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 이미지 Nepeta cataria_12_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_12_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_12_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_12_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_12_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_12_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_12_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_12_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_12_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_12_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_12_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_12_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_12_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_12_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_12_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_12_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_13_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_13_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_13_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 이미지 Nepeta cataria_13_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_13_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_13_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_13_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_13_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 이미지 Nepeta cataria_13_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_13_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_13_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_13_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 이미지 Nepeta cataria_13_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_13_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_13_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_13_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_13_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 이미지 Nepeta cataria_13_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_13_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_13_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 이미지 Nepeta cataria_14_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_14_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_14_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_14_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 이미지 Nepeta cataria_14_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_14_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_14_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 이미지 Nepeta cataria_14_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 이미지 Nepeta cataria_14_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 이미지 Nepeta cataria_14_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 이미지 Nepeta cataria_14_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_14_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_14_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 이미지 Nepeta cataria_14_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 이미지 Nepeta cataria_14_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 이미지 Nepeta cataria_14_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 이미지 Nepeta cataria_14_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_14_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_14_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_14_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_15_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 이미지 Nepeta cataria_15_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 이미지 Nepeta cataria_15_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_15_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_15_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_15_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_15_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_15_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_15_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_15_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_15_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_15_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_15_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_15_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_15_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_15_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_15_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 이미지 Nepeta cataria_15_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_15_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_15_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_16_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_16_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_16_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_16_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_16_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_16_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_16_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_16_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_16_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 이미지 Nepeta cataria_16_18.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_16_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_16_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_16_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_16_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_16_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_16_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_16_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_16_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_16_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_16_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_17_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_17_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_17_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 이미지 Nepeta cataria_17_12.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_17_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_17_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_17_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_17_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_17_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_17_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_17_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_17_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_17_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 이미지 Nepeta cataria_17_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_17_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_17_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_17_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 이미지 Nepeta cataria_17_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_17_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_17_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_18_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_18_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_18_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_18_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_18_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_18_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_18_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_18_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_18_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_18_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_18_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 이미지 Nepeta cataria_18_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_18_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_18_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_18_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_18_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_18_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_18_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_18_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_18_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_19_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_19_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_19_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 이미지 Nepeta cataria_19_12.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 이미지 Nepeta cataria_19_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_19_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_19_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 이미지 Nepeta cataria_19_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_19_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_19_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_19_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_19_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_19_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_19_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_19_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_19_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_19_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_19_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_19_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_19_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_1_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_1_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_1_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_1_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_1_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_1_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_1_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_1_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_1_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_1_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_1_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_1_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_1_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_1_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_1_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_1_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_1_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_1_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_1_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 이미지 Nepeta cataria_1_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_20_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_20_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 이미지 Nepeta cataria_20_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_20_12.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_20_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_20_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_20_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_20_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 이미지 Nepeta cataria_20_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_20_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 이미지 Nepeta cataria_20_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_20_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_20_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_20_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_20_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_20_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_20_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 이미지 Nepeta cataria_20_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_20_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_20_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 이미지 Nepeta cataria_21_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_21_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 이미지 Nepeta cataria_21_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_21_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_21_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_21_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_21_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_21_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 이미지 Nepeta cataria_21_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_21_18.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_21_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_21_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_21_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_21_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_21_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_21_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_21_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_21_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 이미지 Nepeta cataria_21_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_21_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_22_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_22_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_22_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_22_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_22_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_22_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_22_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_22_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_22_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_22_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_22_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_22_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_22_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_22_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_22_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_22_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_22_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_22_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_22_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_22_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_23_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_23_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_23_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_23_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_23_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 이미지 Nepeta cataria_23_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 이미지 Nepeta cataria_23_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_23_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_23_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_23_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_23_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_23_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_23_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_23_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_23_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_23_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_23_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_23_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_23_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_23_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_24_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 이미지 Nepeta cataria_24_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_24_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_24_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_24_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_24_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_24_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_24_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_24_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_24_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 이미지 Nepeta cataria_24_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_24_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_24_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 이미지 Nepeta cataria_24_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_24_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_24_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_24_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 이미지 Nepeta cataria_24_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_24_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_24_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_25_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_25_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_25_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_25_12.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_25_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 이미지 Nepeta cataria_25_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 이미지 Nepeta cataria_25_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_25_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_25_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_25_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_25_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_25_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_25_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 이미지 Nepeta cataria_25_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_25_4.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_25_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_25_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_25_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_25_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_25_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_26_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 이미지 Nepeta cataria_26_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_26_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_26_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_26_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_26_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_26_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_26_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_26_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_26_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 이미지 Nepeta cataria_26_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_26_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_26_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_26_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_26_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_26_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 이미지 Nepeta cataria_26_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_26_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 이미지 Nepeta cataria_26_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_26_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_27_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_27_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_27_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_27_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_27_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_27_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 이미지 Nepeta cataria_27_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 이미지 Nepeta cataria_27_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_27_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_27_18.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_27_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_27_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_27_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_27_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_27_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_27_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_27_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_27_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 이미지 Nepeta cataria_27_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_27_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 이미지 Nepeta cataria_28_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 이미지 Nepeta cataria_28_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_28_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_28_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_28_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_28_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_28_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_28_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_28_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_28_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_28_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_28_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 이미지 Nepeta cataria_28_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_28_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_28_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_28_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 이미지 Nepeta cataria_28_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_28_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_28_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 이미지 Nepeta cataria_28_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 이미지 Nepeta cataria_29_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_29_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 이미지 Nepeta cataria_29_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 이미지 Nepeta cataria_29_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 이미지 Nepeta cataria_29_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_29_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_29_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_29_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_29_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_29_18.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_29_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 이미지 Nepeta cataria_29_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 이미지 Nepeta cataria_29_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_29_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_29_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 이미지 Nepeta cataria_29_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_29_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_29_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_29_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_29_9.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_2_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 이미지 Nepeta cataria_2_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_2_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_2_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 이미지 Nepeta cataria_2_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 이미지 Nepeta cataria_2_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_2_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_2_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_2_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_2_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 이미지 Nepeta cataria_2_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_2_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_2_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 이미지 Nepeta cataria_2_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 이미지 Nepeta cataria_2_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_2_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 이미지 Nepeta cataria_2_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_2_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_2_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_2_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 이미지 Nepeta cataria_30_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_30_10.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 이미지 Nepeta cataria_30_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_30_12.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_30_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_30_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_30_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 이미지 Nepeta cataria_30_16.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_30_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_30_18.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_30_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 이미지 Nepeta cataria_30_2.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_30_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_30_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_30_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_30_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_30_6.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 이미지 Nepeta cataria_30_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_30_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 이미지 Nepeta cataria_30_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 이미지 Nepeta cataria_31_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_31_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 이미지 Nepeta cataria_31_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 이미지 Nepeta cataria_31_12.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_31_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 이미지 Nepeta cataria_31_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 이미지 Nepeta cataria_31_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 이미지 Nepeta cataria_31_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_31_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 이미지 Nepeta cataria_31_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_31_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 이미지 Nepeta cataria_31_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 이미지 Nepeta cataria_31_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_31_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 이미지 Nepeta cataria_31_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 이미지 Nepeta cataria_31_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 이미지 Nepeta cataria_31_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 이미지 Nepeta cataria_31_7.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 이미지 Nepeta cataria_31_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_31_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 이미지 Nepeta cataria_32_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_32_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 이미지 Nepeta cataria_32_3.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 이미지 Nepeta cataria_32_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 이미지 Nepeta cataria_3_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 이미지 Nepeta cataria_3_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 이미지 Nepeta cataria_3_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 이미지 Nepeta cataria_3_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 이미지 Nepeta cataria_3_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 이미지 Nepeta cataria_3_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 이미지 Nepeta cataria_3_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_3_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 이미지 Nepeta cataria_3_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 이미지 Nepeta cataria_3_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 이미지 Nepeta cataria_3_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 이미지 Nepeta cataria_3_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 이미지 Nepeta cataria_3_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 이미지 Nepeta cataria_3_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_3_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 이미지 Nepeta cataria_3_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 이미지 Nepeta cataria_3_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 이미지 Nepeta cataria_3_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 이미지 Nepeta cataria_3_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_3_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 이미지 Nepeta cataria_4_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 이미지 Nepeta cataria_4_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 이미지 Nepeta cataria_4_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 이미지 Nepeta cataria_4_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 이미지 Nepeta cataria_4_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 이미지 Nepeta cataria_4_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 이미지 Nepeta cataria_4_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 이미지 Nepeta cataria_4_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 이미지 Nepeta cataria_4_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 이미지 Nepeta cataria_4_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 이미지 Nepeta cataria_4_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 이미지 Nepeta cataria_4_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 이미지 Nepeta cataria_4_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 이미지 Nepeta cataria_4_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 이미지 Nepeta cataria_4_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 이미지 Nepeta cataria_4_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 이미지 Nepeta cataria_4_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 이미지 Nepeta cataria_4_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 이미지 Nepeta cataria_4_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_4_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 이미지 Nepeta cataria_5_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 이미지 Nepeta cataria_5_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 이미지 Nepeta cataria_5_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 이미지 Nepeta cataria_5_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 이미지 Nepeta cataria_5_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 이미지 Nepeta cataria_5_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 이미지 Nepeta cataria_5_15.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 이미지 Nepeta cataria_5_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 이미지 Nepeta cataria_5_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 이미지 Nepeta cataria_5_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 이미지 Nepeta cataria_5_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 이미지 Nepeta cataria_5_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_5_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 이미지 Nepeta cataria_5_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 이미지 Nepeta cataria_5_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 이미지 Nepeta cataria_5_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 이미지 Nepeta cataria_5_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 이미지 Nepeta cataria_5_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 이미지 Nepeta cataria_5_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 이미지 Nepeta cataria_5_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 이미지 Nepeta cataria_6_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 이미지 Nepeta cataria_6_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 이미지 Nepeta cataria_6_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 이미지 Nepeta cataria_6_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_6_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 이미지 Nepeta cataria_6_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 이미지 Nepeta cataria_6_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 이미지 Nepeta cataria_6_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 이미지 Nepeta cataria_6_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 이미지 Nepeta cataria_6_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 이미지 Nepeta cataria_6_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 이미지 Nepeta cataria_6_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 이미지 Nepeta cataria_6_20.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 이미지 Nepeta cataria_6_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 이미지 Nepeta cataria_6_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 이미지 Nepeta cataria_6_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 이미지 Nepeta cataria_6_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 이미지 Nepeta cataria_6_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 이미지 Nepeta cataria_6_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 이미지 Nepeta cataria_6_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 이미지 Nepeta cataria_7_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 이미지 Nepeta cataria_7_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 이미지 Nepeta cataria_7_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 이미지 Nepeta cataria_7_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 이미지 Nepeta cataria_7_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 이미지 Nepeta cataria_7_14.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 이미지 Nepeta cataria_7_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 이미지 Nepeta cataria_7_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 이미지 Nepeta cataria_7_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 이미지 Nepeta cataria_7_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 이미지 Nepeta cataria_7_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 이미지 Nepeta cataria_7_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 이미지 Nepeta cataria_7_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 이미지 Nepeta cataria_7_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 이미지 Nepeta cataria_7_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_7_5.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 이미지 Nepeta cataria_7_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 이미지 Nepeta cataria_7_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 이미지 Nepeta cataria_7_8.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 이미지 Nepeta cataria_7_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 이미지 Nepeta cataria_8_1.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 이미지 Nepeta cataria_8_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 이미지 Nepeta cataria_8_11.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_8_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 이미지 Nepeta cataria_8_13.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 이미지 Nepeta cataria_8_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 이미지 Nepeta cataria_8_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 이미지 Nepeta cataria_8_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 이미지 Nepeta cataria_8_17.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 이미지 Nepeta cataria_8_18.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 이미지 Nepeta cataria_8_19.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 이미지 Nepeta cataria_8_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 이미지 Nepeta cataria_8_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_8_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 이미지 Nepeta cataria_8_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 이미지 Nepeta cataria_8_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 이미지 Nepeta cataria_8_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 이미지 Nepeta cataria_8_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 이미지 Nepeta cataria_8_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 이미지 Nepeta cataria_8_9.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 이미지 Nepeta cataria_9_1.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_9_10.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 이미지 Nepeta cataria_9_11.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 이미지 Nepeta cataria_9_12.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_9_13.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 이미지 Nepeta cataria_9_14.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 이미지 Nepeta cataria_9_15.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 이미지 Nepeta cataria_9_16.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 이미지 Nepeta cataria_9_17.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 이미지 Nepeta cataria_9_18.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 이미지 Nepeta cataria_9_19.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 이미지 Nepeta cataria_9_2.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 이미지 Nepeta cataria_9_20.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 이미지 Nepeta cataria_9_3.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 이미지 Nepeta cataria_9_4.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_9_5.jpg를 can_not_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 이미지 Nepeta cataria_9_6.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 이미지 Nepeta cataria_9_7.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 이미지 Nepeta cataria_9_8.jpg를 can_use 폴더에 저장했습니다.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 이미지 Nepeta cataria_9_9.jpg를 can_not_use 폴더에 저장했습니다.
